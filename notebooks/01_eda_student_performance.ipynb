# %% [markdown]
# # Exploratory Data Analysis (EDA): Student Academic Performance Dataset
#
# ## Purpose
# This notebook presents an exploratory analysis of the student academic performance dataset developed for the study **“Predictive Analytics for Student Academic Performance in Nigerian Tertiary Institutions Using Machine Learning Techniques.”** The analysis is organised to support Chapter Three (Methodology) by:
#
# - describing the dataset structure and distributional properties;
# - assessing missingness patterns (as a data quality consideration);
# - examining class imbalance in the target variable;
# - examining correlation patterns among numeric variables to identify redundancy and plausible associations.
#
# ## Reproducibility Note
# All results in this notebook are generated directly from the CSV file and are therefore reproducible under the same dataset version.

# %% [markdown]
# from __future__ import annotations
#
# from pathlib import Path
#
# import numpy as np
# import pandas as pd
# import matplotlib.pyplot as plt
# import seaborn as sns
#
# sns.set_theme(style="whitegrid")
#
# DATA_PATH = Path("..") / "data" / "raw" / "synthetic_student_dataset.csv"
# TARGET_COL = "performance_risk"
#
# df = pd.read_csv(DATA_PATH)
#
# print("Dataset shape:", df.shape)
# display(df.head(5))
#
# display(df.dtypes)

# %% [markdown]
# ## 1. Descriptive Statistics
# This section summarises the central tendencies and dispersion of the numerical variables, and provides frequency distributions for selected categorical variables. In an academic context, these summaries provide an initial assessment of plausibility, scale consistency, and potential outliers that may affect modeling decisions.
